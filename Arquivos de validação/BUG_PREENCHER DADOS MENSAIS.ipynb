# %% [markdown]
# ## 🔴 Relatório de Bug: PREENCHIMENTO DOS DADOS DE RENDIMENTOS
#
# **Bug Identificado:** A telha de preenchimento de dados mensais apresenta vários problemas.
# 1. O formato de inserir os dados que está limitada ao perído de janeiro de 2017 até dezembro de 2025 de forma ingessada (sem fleximidiade) e a 108 valores. O formato correto é de tabela com três conulas onde o usuário pode preencher quandos valores desejar e os meses são números `1, 2, 3,....,108,...1000`, a coluna de obseração é de preenchimento opcional:
#
# | Nº do Mês | Retrono do mês (%) | Observação |
# |---------|---------------|-------------|
# | 1 | 0,25 | |
# | 2 | 3,15 | `comentário opcional` |
# | 3 | 1,08 | |
# ...
#
#
# `Esse formato da tabela deve ser o mesmo para o modelo de inportação e exportação`
#
# **Severidade:** 🔴 CRÍTICO
